# %% [markdown]
# ## October Surprise 2016

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_2016 = pd.read_csv("2016_clean.csv", parse_dates = ['interview_start_date', 'interview_end_date'])

# %%
df_2016
# Out:
#       Unnamed: 0  ft_dem  ft_rep  caseid interview_mode   age     gender  \
# 0           1180    71.0     2.0  2001.0         2. Web  51.0    1. Male
# 1           1182    85.0     0.0  2003.0         2. Web  56.0    1. Male
# 2           1183    70.0     0.0  2004.0         2. Web  20.0  2. Female
# 3           1184    42.0    50.0  2005.0         2. Web  26.0  2. Female
# 4           1185    70.0     0.0  2006.0         2. Web  41.0    1. Male
# ...          ...     ...     ...     ...            ...   ...        ...
# 3029        4265    86.0     3.0  5086.0         2. Web  37.0  2. Female
# 3030        4266    50.0   100.0  5087.0         2. Web  82.0    1. Male
# 3031        4267     0.0    86.0  5088.0         2. Web  27.0    1. Male
# 3032        4268    85.0     0.0  5089.0         2. Web  39.0  2. Female
# 3033        4269    60.0    40.0  5090.0         2. Web  52.0    1. Male
#
#      interview_start_date interview_start_time interview_end_date  \
# ...

# %%
groupped_df = df_2016.groupby('interview_start_date', as_index=False)

# %%
mean_ft_dem = df_2016.groupby('interview_start_date', as_index=False)['ft_dem'].mean()
mean_ft_dem = mean_ft_dem.set_index("interview_start_date")
mean_ft_dem
# Out:
#                          ft_dem
# interview_start_date
# 2016-09-10            45.750000
# 2016-09-12            37.108225
# 2016-09-13            44.133880
# 2016-09-14            40.314607
# 2016-09-15            41.767123
# 2016-09-16            41.953947
# 2016-09-17            46.116279
# 2016-09-18            38.632479
# 2016-09-19            42.694444
# 2016-09-20            42.945946
# 2016-09-21            38.955224
# 2016-09-22            45.272727
# 2016-09-23            37.937500
# 2016-09-24            43.888889
# 2016-09-25            46.172414
# 2016-09-26            35.000000
# 2016-09-27            54.250000
# 2016-09-28            48.560000
# 2016-09-29            37.074074
# 2016-09-30            48.358491
# 2016-10-01            38.166667
# 2016-10-02            58.961538
# 2016-10-03            37.923077
# 2016-10-04            45.285714
# 2016-10-05            54.076923
# 2016-10-06            51.588235
# 2016-10-07            35.625000
# ...

# %%
mean_ft_rep = df_2016.groupby('interview_start_date', as_index=False)['ft_rep'].mean()
mean_ft_rep = mean_ft_rep.set_index("interview_start_date")
mean_ft_rep
# Out:
#                          ft_rep
# interview_start_date
# 2016-09-10            21.750000
# 2016-09-12            39.095238
# 2016-09-13            35.322404
# 2016-09-14            39.449438
# 2016-09-15            35.143836
# 2016-09-16            40.078947
# 2016-09-17            34.906977
# 2016-09-18            35.726496
# 2016-09-19            36.546296
# 2016-09-20            29.040541
# 2016-09-21            40.044776
# 2016-09-22            39.795455
# 2016-09-23            41.062500
# 2016-09-24            34.166667
# 2016-09-25            37.137931
# 2016-09-26            48.942857
# 2016-09-27            29.750000
# 2016-09-28            27.640000
# 2016-09-29            39.574074
# 2016-09-30            30.886792
# 2016-10-01            33.500000
# 2016-10-02            18.769231
# 2016-10-03            38.576923
# 2016-10-04            41.619048
# 2016-10-05            33.230769
# 2016-10-06            33.294118
# 2016-10-07            50.000000
# ...

# %%
demblue = "#0015BC"
repred = "#FF0000"
demgrey = "#9EA4BF"
repgrey = "#BF9EA2"

# %%
fig, ax = plt.subplots(figsize=(16, 8))

sns.lineplot(
    data = mean_ft_dem, 
    ax = ax,
    x = "interview_start_date", 
    y = "ft_dem",
    color = demblue
)
sns.lineplot(
    data = mean_ft_rep, 
    ax = ax,
    x = "interview_start_date", 
    y = "ft_rep",
    color = repred
)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_xlabel("Interview Start Date", fontsize=16)
ax.set_ylabel("Feeling Thermometer Temperature", fontsize=16)
ax.set_title("2016 ANES Survey Feeling Thermometer", fontsize=22)
# Out:
# Text(0.5, 1.0, '2016 ANES Survey Feeling Thermometer')

# %%
import datetime

start_date = datetime.datetime(2016, 10, 25)
end_date = datetime.datetime(2016, 11, 1)

print(f"{start_date=}; {end_date=}")
# Out:
# start_date=datetime.datetime(2016, 10, 25, 0, 0); end_date=datetime.datetime(2016, 11, 1, 0, 0)

# %%
df_surprise = df_2016[ df_2016["interview_start_date"] >= start_date ]

# %%
df_surprise = df_surprise[ df_surprise["interview_start_date"] <= end_date ]

# %%
groupped_df = df_surprise.groupby('interview_start_date', as_index=False)

# %%
mean_ft_dem_surprise = df_surprise.groupby('interview_start_date', as_index=False)['ft_dem'].mean()
mean_ft_dem_surprise = mean_ft_dem_surprise.set_index("interview_start_date")
mean_ft_dem_surprise
# Out:
#                          ft_dem
# interview_start_date
# 2016-10-25            32.967742
# 2016-10-26            38.851852
# 2016-10-27            39.357143
# 2016-10-28            39.541667
# 2016-10-29            38.055556
# 2016-10-30            45.555556
# 2016-10-31            39.647059
# 2016-11-01            42.500000

# %%
mean_ft_rep_surprise = df_surprise.groupby('interview_start_date', as_index=False)['ft_rep'].mean()
mean_ft_rep_surprise = mean_ft_rep_surprise.set_index("interview_start_date")
mean_ft_rep_surprise
# Out:
#                          ft_rep
# interview_start_date
# 2016-10-25            38.419355
# 2016-10-26            33.148148
# 2016-10-27            46.500000
# 2016-10-28            39.875000
# 2016-10-29            39.277778
# 2016-10-30            16.222222
# 2016-10-31            42.058824
# 2016-11-01            42.714286

# %%
fig, ax = plt.subplots(figsize=(16, 8))

sns.lineplot(
    data = mean_ft_dem_surprise, 
    ax = ax,
    x = "interview_start_date", 
    y = "ft_dem",
    color = demblue
)
sns.lineplot(
    data = mean_ft_rep_surprise, 
    ax = ax,
    x = "interview_start_date", 
    y = "ft_rep",
    color = repred
)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_xlabel("Interview Start Date", fontsize=16)
ax.set_ylabel("Feeling Thermometer Temperature", fontsize=16)
ax.set_title("2016 ANES Survey Around October Surprise", fontsize=22)
# Out:
# Text(0.5, 1.0, '2016 ANES Survey Around October Surprise')

# %%
df_twitter_rep = pd.read_csv('data/trump_twts_2016_classified_senti+poli.csv', parse_dates=['time'])
#df_twitter_rep.head()

# %%
df_twitter_dem = pd.read_csv('data/clinton_twts_2016_classified_senti+poli.csv',  parse_dates=['time'])
#df_twitter_dem.head()

# %%
dfClinton = pd.read_csv("data/2016_twitter_dem_mean_sentiment.csv", parse_dates=['time'])
dfTrump = pd.read_csv("data/2016_twitter_rep_mean_sentiment.csv", parse_dates=['time'])

# %%
df_twitter_rep_surprise = dfTrump[ (dfTrump["time"].dt.date >=  start_date.date()) & (dfTrump["time"].dt.date <=  end_date.date()) ]
df_twitter_rep_surprise
# Out:
#          time        twt_id  sentiment_label  sentiment_score  political_score
# 48 2016-10-25  7.908956e+17        -0.671504         0.963476         0.957107
# 49 2016-10-26  7.912718e+17        -0.587968         0.955216         0.956956
# 50 2016-10-27  7.916297e+17        -0.645269         0.958451         0.960325
# 51 2016-10-28  7.919784e+17        -0.627228         0.959230         0.962916
# 52 2016-10-29  7.923444e+17        -0.638612         0.959239         0.964886
# 53 2016-10-30  7.927208e+17        -0.588318         0.952982         0.961746
# 54 2016-10-31  7.930921e+17        -0.605865         0.950019         0.962498
# 55 2016-11-01  7.934266e+17        -0.639610         0.954451         0.961359

# %%
df_twitter_dem_surprise = dfClinton[ (dfClinton["time"].dt.date >=  start_date.date()) & (dfClinton["time"].dt.date <=  end_date.date()) ]
df_twitter_dem_surprise
# Out:
#          time        twt_id  sentiment_label  sentiment_score  political_score
# 48 2016-10-25  7.909007e+17        -0.692825         0.950338         0.976957
# 49 2016-10-26  7.912640e+17        -0.551845         0.943374         0.974978
# 50 2016-10-27  7.916334e+17        -0.557891         0.948597         0.974280
# 51 2016-10-28  7.920249e+17        -0.754796         0.966682         0.975412
# 52 2016-10-29  7.923272e+17        -0.806494         0.967402         0.979301
# 53 2016-10-30  7.927232e+17        -0.778711         0.957506         0.979781
# 54 2016-10-31  7.930700e+17        -0.786441         0.959534         0.958015
# 55 2016-11-01  7.934378e+17        -0.691176         0.954791         0.973030

# %%
fig, ax = plt.subplots(figsize=(16, 8))

sns.lineplot(
    data = df_twitter_dem_surprise, 
    ax = ax,
    x = "time", 
    y = "sentiment_label",
    color = demblue
)
sns.lineplot(
    data = df_twitter_rep_surprise, 
    ax = ax,
    x = "time", 
    y = "sentiment_label",
    color = repred
)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_xlabel("Date", fontsize=16)
ax.set_ylabel("Sentiment Score", fontsize=16)
ax.set_title("2016 Twitter Sentiment Around October Surprise", fontsize=22)
# Out:
# Text(0.5, 1.0, '2016 Twitter Sentiment Around October Surprise')

# %%
fig, ax = plt.subplots(figsize=(16, 8))

sns.lineplot(
    data = df_twitter_dem_surprise, 
    ax = ax,
    x = "time", 
    y = "sentiment_label",
    color = demblue,
    linewidth = 5
)
sns.lineplot(
    data = df_twitter_rep_surprise, 
    ax = ax,
    x = "time", 
    y = "sentiment_label",
    color = repred,
    linewidth = 5
)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_xlabel("Date", fontsize=16)
ax.set_ylabel("Twitter Sentiment Score", fontsize=16)
ax.set_title("2016 Sentiment Around October Surprise", fontsize=22)


plt.legend(
    labels = ["Mean Twitter Sentiment (Dem)","Mean Twitter Sentiment (Rep)"], 
    loc = 3
)

ax2 = plt.twinx()

sns.lineplot(
    data = mean_ft_dem_surprise, 
    ax = ax2,
    x = "interview_start_date", 
    y = "ft_dem",
    color = demgrey,
    linewidth = 5
)
sns.lineplot(
    data = mean_ft_rep_surprise, 
    ax = ax2,
    x = "interview_start_date", 
    y = "ft_rep",
    color = repgrey,
    linewidth = 5
)

ax2.spines['left'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.spines['bottom'].set_visible(False)

ax2.set_ylabel("Feeling Thermometer Temperature (Rescaled)", fontsize=16)

plt.legend(
    labels = ["Mean Feeling Temperature (Dem)","Mean Feeling Temperature (Rep)"], 
    loc = 4
)


plt.axvline(
    pd.Timestamp('2016-10-28'),
    color = "k",
    linestyle = "--"
)

# %%
from numpy.random import randn
from numpy.random import seed
from scipy.stats import spearmanr

corr, _ = spearmanr(mean_ft_dem_surprise["ft_dem"], df_twitter_dem_surprise["sentiment_label"])
print('Spearmans correlation: %.3f' % corr)
# Out:
# Spearmans correlation: -0.119

# %%
corr, _ = spearmanr(mean_ft_rep_surprise["ft_rep"], df_twitter_rep_surprise["sentiment_label"])
print('Spearmans correlation: %.3f' % corr)
# Out:
# Spearmans correlation: -0.524
