# %% [markdown]
# # American National Election Studies 2012
#
# The data was downloaded from American National Election Studies [2012 Time Series Study](https://electionstudies.org/data-center/2012-time-series-study/).
#
#
# ## Study Overview
# ### Study Content Highlights:
# In addition to content on electoral participation, voting behavior, and public opinion, the 2012 ANES Time Series Study contains questions in other areas such as media exposure, cognitive style, and values and predispositions. Several items were measured on ANES for the first time, including ‘Big Five’ personality traits using the Ten Item Personality Inventory (TIPI), skin tone observations made by interviewers in the face-to-face study, and a vocabulary test from the General Social Survey called ‘Wordsum.’ The Post-Election interview also included Module 4 from the Comparative Study of Electoral Systems (CSES).
#
# ### Study Design Highlights:
# Data collection for the ANES 2012 Time Series Study began in early September and continued into January, 2013. Pre-election interviews were conducted with study respondents during the two months prior to the 2012 elections and were followed by post-election reinterviewing beginning November 7, 2012.

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', 1000)

# %%
df = pd.read_spss('data/anes_timeseries_2012.sav')

# %%
df.shape
# Out:
# (5914, 2249)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5914 entries, 0 to 5913
# Columns: 2249 entries, version to invited_inetrecontact2013
# dtypes: category(2180), float64(10), object(59)
# memory usage: 16.6+ MB

# %%
df.sample(3, replace=False)
# Out:
#                                  version  caseid  weight_ftf  weight_web  \
# 2791  ANES2012TimeSeries_version20160504  3738.0         0.0       0.417
# 3326  ANES2012TimeSeries_version20160504  4273.0         0.0       0.328
# 4079  ANES2012TimeSeries_version20160504  5027.0         0.0       2.971
#
#       weight_full  psu_full  psu_ftf  strata_full  strata_ftf  \
# 2791        0.417     862.0      NaN         10.0         NaN
# 3326        0.328    1397.0      NaN         10.0         NaN
# 4079        2.971    2151.0      NaN         10.0         NaN
#
#         ftf_oversample                                   wave_completions  \
# 2791  -1. Inapplicable  1. Yes (pre-election and post-election intervi...
# 3326  -1. Inapplicable  1. Yes (pre-election and post-election intervi...
# 4079  -1. Inapplicable  1. Yes (pre-election and post-election intervi...
#
#                   mode      gend_gendobs gender_respondent_x  \
# 2791  2. Internet mode  -1. Inapplicable             1. Male
# 3326  2. Internet mode  -1. Inapplicable           2. Female
# 4079  2. Internet mode  -1. Inapplicable           2. Female
#
#        interest_attention      interest_following interest_wherevote  \
# 2791  4. Some of the time  3. Not much interested             1. Yes
# 3326  2. Most of the time  2. Somewhat interested             1. Yes
# 4079  4. Some of the time  2. Somewhat interested              2. No
#
#       interest_voted2008 interest_whovote2008  \
# 2791       1. Yes, voted       2. John mccain
# 3326  2. No, didn't vote     -1. Inapplicable
# 4079       1. Yes, voted   5. Other {SPECIFY}
#
#                            interest_whovote2008_oth   prmedia_useinet  \
# 2791  -2. Text responses available in separate file  -1. Inapplicable
# 3326  -2. Text responses available in separate file  -1. Inapplicable
# 4079  -2. Text responses available in separate file  -1. Inapplicable
#
#      prmedia_wkinews       prmedia_atinews prmedia_wktvnws  prmedia_attvnews  \
# 2791      1. One day           4. A little         0. None  -1. Inapplicable
# 3326   7. Seven days  3. A moderate amount         0. None  -1. Inapplicable
# 4079         0. None      -1. Inapplicable     2. Two days       4. A little
#
#      prmedia_wkpaprnws prmedia_atpprnews prmedia_wkrdnws  prmedia_atrdnews  \
# 2791           0. None  -1. Inapplicable      1. One day    5. None at all
# 3326           0. None  -1. Inapplicable         0. None  -1. Inapplicable
# 4079           0. None  -1. Inapplicable      1. One day       4. A little
#
#                        prevote_regist_addr prevote_regist_noaddr  \
# 2791  2. Registered at a different address      -1. Inapplicable
# 3326         1. Registered at this address      -1. Inapplicable
# 4079  2. Registered at a different address      -1. Inapplicable
#
#            prevote_reg prevote_reg_recordstate prevote_reg_recordcity  \
# 2791  -1. Inapplicable        -1. Inapplicable       -1. Inapplicable
# 3326  -1. Inapplicable        -1. Inapplicable       -1. Inapplicable
# 4079  -1. Inapplicable        -1. Inapplicable       -1. Inapplicable
#
#      prevote_reg_state prevote_reg_samestate  \
# 2791  -1. Inapplicable      -1. Inapplicable
# 3326  -1. Inapplicable      -1. Inapplicable
# 4079  -1. Inapplicable      -1. Inapplicable
#
#                               prevote_regincnty    prevote_regyrs3cat  \
# 2791  1. Yes, registered in [preload: hhcounty]  3. More than 5 years
# 3326                           -1. Inapplicable          1. 0-1 years
# 4079  1. Yes, registered in [preload: hhcounty]  3. More than 5 years
#
#          prevote_regyrsfull         prevote_regname  \
# 2791  -3. Restricted access  1.  text in name field
# 3326  -3. Restricted access  1.  text in name field
# 4079  -3. Restricted access  1.  text in name field
#
#                                    prevote_regpty_state    prevote_regpty  \
# 2791  0. Not not registered in state in with party r...  -1. Inapplicable
# 3326  0. Not not registered in state in with party r...  -1. Inapplicable
# 4079  0. Not not registered in state in with party r...  -1. Inapplicable
#
#          prevote_regpty_oth    prevote_regint  \
# 2791  -3. Restricted access  -1. Inapplicable
# 3326  -3. Restricted access  -1. Inapplicable
# 4079  -3. Restricted access  -1. Inapplicable
#
#                                 prevote_primv  prevote_primvwho  \
# 2791  2. No, didn't vote in primary or caucus  -1. Inapplicable
# 3326  2. No, didn't vote in primary or caucus  -1. Inapplicable
# 4079  2. No, didn't vote in primary or caucus  -1. Inapplicable
#
#                                prevote_primvwho_oth      prevote_voted  \
# 2791  -2. Text responses available in separate file  2. Have not voted
# 3326  -2. Text responses available in separate file  2. Have not voted
# 4079  -2. Text responses available in separate file  2. Have not voted
#
#          prevote_vconf   prevote_howvote  \
# 2791  -1. Inapplicable  -1. Inapplicable
# 3326  -1. Inapplicable  -1. Inapplicable
# 4079  -1. Inapplicable  -1. Inapplicable
#
#                                         prevote_ckbcard prevote_ballot_color  \
# 2791  3. Only have card(s) for wrong district or hav...     -1. Inapplicable
# 3326  1. Yes, have [blue/pink] color ballot card for...     -1. Inapplicable
# 4079  3. Only have card(s) for wrong district or hav...     -1. Inapplicable
#
#         prevote_presvt prevote_presvtwho  \
# 2791  -1. Inapplicable  -1. Inapplicable
# 3326  -1. Inapplicable  -1. Inapplicable
# 4079  -1. Inapplicable  -1. Inapplicable
#
#                               prevote_presvtwho_oth   prevote_presstr  \
# 2791  -2. Text responses available in separate file  -1. Inapplicable
# 3326  -2. Text responses available in separate file  -1. Inapplicable
# 4079  -2. Text responses available in separate file  -1. Inapplicable
#
#                                   prevote_vtpresdec prevote_vtpresdec_dkrf  \
# 2791  -2. Text responses available in separate file       -1. Inapplicable
# 3326  -2. Text responses available in separate file       -1. Inapplicable
# 4079  -2. Text responses available in separate file       -1. Inapplicable
#
#      prevote_intpres            prevote_intpreswho  \
# 2791           2. No              -1. Inapplicable
# 3326          1. Yes      1. [preload: dem_pcname]
# 4079          1. Yes  5. Other candidate {SPECIFY}
#
#                              prevote_intpreswho_oth prevote_intpresst  \
# 2791  -2. Text responses available in separate file  -1. Inapplicable
# 3326  -2. Text responses available in separate file         1. Strong
# 4079  -2. Text responses available in separate file     2. Not strong
#
#       prevote_prefpres prevote_prefprwho  \
# 2791  -1. Inapplicable  -1. Inapplicable
# 3326  -1. Inapplicable  -1. Inapplicable
# 4079  -1. Inapplicable  -1. Inapplicable
#
#                               prevote_prefprwho_oth prevote_prefprstr  \
# 2791  -2. Text responses available in separate file  -1. Inapplicable
# 3326  -2. Text responses available in separate file  -1. Inapplicable
# 4079  -2. Text responses available in separate file  -1. Inapplicable
#
#         prevote_votehs    prevote_hsvtbc  prevote_hsvtnobc prevote_inths  \
# 2791  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable         2. No
# 3326  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable        1. Yes
# 4079  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable        1. Yes
#
#                 prevote_inthsbc prevote_inthsnobc    prevote_hspref  \
# 2791           -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
# 3326  1. [preload: dem_hsename]  -1. Inapplicable  -1. Inapplicable
# 4079           -1. Inapplicable      81. Democrat  -1. Inapplicable
#
#       prevote_hsprefbc prevote_hsprefnobc prevote_senhhstate  \
# 2791  -1. Inapplicable   -1. Inapplicable   -1. Inapplicable
# 3326  -1. Inapplicable   -1. Inapplicable   -1. Inapplicable
# 4079  -1. Inapplicable   -1. Inapplicable   -1. Inapplicable
#
#      prevote_senregstate   prevote_votesen   prevote_vtsenbc  \
# 2791    -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
# 3326    -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
# 4079    -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
#
#      prevote_vtsennobc prevote_intsen              prevote_intsenbc  \
# 2791  -1. Inapplicable          2. No              -1. Inapplicable
# 3326  -1. Inapplicable         1. Yes     1. [preload: dem_senname]
# 4079  -1. Inapplicable         1. Yes  5. Other candidate {SPECIFY}
#
#      prevote_intsennobc   prevote_senpref prevote_senprefbc  \
# 2791        -9. Refused  -1. Inapplicable  -1. Inapplicable
# 3326   -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
# 4079   -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
#
#      prevote_senprefnobc prevote_govhhstate prevote_govregstate  \
# 2791    -1. Inapplicable   -1. Inapplicable    -1. Inapplicable
# 3326    -1. Inapplicable   -1. Inapplicable    -1. Inapplicable
# 4079    -1. Inapplicable   -1. Inapplicable    -1. Inapplicable
#
#        prevote_votegov   prevote_vtgovbc prevote_vtgovnobc    prevote_intgov  \
# 2791  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
# 3326  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable            1. Yes
# 4079  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
#
#                prevote_intgovbc prevote_intgovnobc   prevote_govpref  \
# 2791           -1. Inapplicable   -1. Inapplicable  -1. Inapplicable
# 3326  1. [preload: dem_govname]   -1. Inapplicable  -1. Inapplicable
# 4079           -1. Inapplicable   -1. Inapplicable  -1. Inapplicable
#
#      prevote_govprefbc prevote_govprefnobc candlik_likedpc  \
# 2791  -1. Inapplicable    -1. Inapplicable           2. No
# 3326  -1. Inapplicable    -1. Inapplicable          1. Yes
# 4079  -1. Inapplicable    -1. Inapplicable          1. Yes
#
#                                 candlik_likewhatdpc candlik_disldpc  \
# 2791  -2. Text responses available in separate file           2. No
# 3326  -2. Text responses available in separate file           2. No
# 4079  -2. Text responses available in separate file          1. Yes
#
#                                 candlik_dislwhatdpc candlik_likerpc  \
# 2791  -2. Text responses available in separate file           2. No
# 3326  -2. Text responses available in separate file           2. No
# 4079  -2. Text responses available in separate file           2. No
#
#                                 candlik_likewhatrpc candlik_dislrpc  \
# 2791  -2. Text responses available in separate file           2. No
# 3326  -2. Text responses available in separate file          1. Yes
# 4079  -2. Text responses available in separate file          1. Yes
#
#                                 candlik_dislwhatrpc    congapp_job  \
# 2791  -2. Text responses available in separate file  2. Disapprove
# 3326  -2. Text responses available in separate file     1. Approve
# 4079  -2. Text responses available in separate file  2. Disapprove
#
#         congapp_jobst               congapp_job_x       presapp_track  \
# 2791      1. Strongly      5. Disapprove strongly      2. Wrong track
# 3326  2. Not strongly     2. Approve not strongly  1. Right direction
# 4079  2. Not strongly  4. Disapprove not strongly  1. Right direction
#
#         presapp_job   presapp_jobstr               presapp_job_x  \
# 2791  2. Disapprove  2. Not strongly  4. Disapprove not strongly
# 3326     1. Approve      1. Strongly         1. Approve strongly
# 4079     1. Approve  2. Not strongly     2. Approve not strongly
#
#        presapp_econ  presapp_econstr           presapp_econ_x presapp_foreign  \
# 2791  2. Disapprove      1. Strongly   5. Disapprove strongly   2. Disapprove
# 3326     1. Approve  2. Not strongly  2. Approve not strongly      1. Approve
# 4079     1. Approve      1. Strongly      1. Approve strongly      1. Approve
#
#      presapp_foreignstr        presapp_foreign_x presapp_health  \
# 2791        1. Strongly   5. Disapprove strongly  2. Disapprove
# 3326        1. Strongly      1. Approve strongly     1. Approve
# 4079    2. Not strongly  2. Approve not strongly     1. Approve
#
#      presapp_healthstr         presapp_health_x    presapp_war  \
# 2791       1. Strongly   5. Disapprove strongly  2. Disapprove
# 3326       1. Strongly      1. Approve strongly     1. Approve
# 4079   2. Not strongly  2. Approve not strongly     1. Approve
#
#        presapp_warstr               presapp_war_x ft_dpc ft_rpc ft_dvpc  \
# 2791  2. Not strongly  4. Disapprove not strongly   50.0   65.0    40.0
# 3326  2. Not strongly     2. Approve not strongly   90.0    0.0    80.0
# 4079  2. Not strongly     2. Approve not strongly   70.0    0.0    70.0
#
#      ft_rvpc ft_hclinton ft_gwb ft_dem ft_rep ptylik_likdp  \
# 2791    70.0        10.0   70.0   45.0   60.0        2. No
# 3326     0.0        85.0    0.0   90.0    0.0        2. No
# 4079     0.0        60.0   70.0   70.0   15.0       1. Yes
#
#                                      ptylik_lwhatdp ptylik_disldp  \
# 2791  -2. Text responses available in separate file         2. No
# 3326  -2. Text responses available in separate file         2. No
# 4079  -2. Text responses available in separate file        1. Yes
#
#                                      ptylik_dwhatdp ptylik_likrp  \
# 2791  -2. Text responses available in separate file        2. No
# 3326  -2. Text responses available in separate file        2. No
# 4079  -2. Text responses available in separate file        2. No
#
#                                      ptylik_lwhatrp ptylik_dislrp  \
# 2791  -2. Text responses available in separate file         2. No
# 3326  -2. Text responses available in separate file        1. Yes
# 4079  -2. Text responses available in separate file        1. Yes
#
#                                      ptylik_dwhatrp  \
# 2791  -2. Text responses available in separate file
# 3326  -2. Text responses available in separate file
# 4079  -2. Text responses available in separate file
#
#                       finance_finfam finance_finpast finance_finpastamt  \
# 2791            1. One family member        2. Worse        2. Somewhat
# 3326          4. Four family members       1. Better        2. Somewhat
# 4079  5. Five or more family members       1. Better        2. Somewhat
#
#        finance_finpast_x finance_finnext finance_finnextamt  \
# 2791   4. Somewhat worse        2. Worse        2. Somewhat
# 3326  2. Somewhat better       1. Better        2. Somewhat
# 4079  2. Somewhat better       1. Better            1. Much
#
#        finance_finnext_x health_insured               health_2010hcr  \
# 2791   4. Somewhat worse         1. Yes                    2. Oppose
# 3326  2. Somewhat better         1. Yes                     1. Favor
# 4079      1. Much better          2. No  3. Neither favor nor oppose
#
#      health_2010hcrfav health_2010hcropp             health_2010hcr_x  \
# 2791  -1. Inapplicable     2. Moderately         6. Oppose moderately
# 3326   1. A great deal  -1. Inapplicable        1. Favor a great deal
# 4079  -1. Inapplicable  -1. Inapplicable  4. Neither favor nor oppose
#
#        health_self health_smoke   health_smokeamt candaff_angdpc  \
# 2791  2. Very good        2. No  -1. Inapplicable         1. Yes
# 3326  2. Very good        2. No  -1. Inapplicable          2. No
# 4079       3. Good       1. Yes     3. Not at all         1. Yes
#
#         candaff_angdpcoft candaff_hpdpc        candaff_hpdpcoft  \
# 2791  4. Some of the time         2. No        -1. Inapplicable
# 3326     -1. Inapplicable        1. Yes  3. About half the time
# 4079  4. Some of the time        1. Yes     4. Some of the time
#
#      candaff_afrdpc candaff_afrdpcoft candaff_prddpc    candaff_prddpcoft  \
# 2791          2. No  -1. Inapplicable          2. No     -1. Inapplicable
# 3326          2. No  -1. Inapplicable         1. Yes  2. Most of the time
# 4079          2. No  -1. Inapplicable         1. Yes  4. Some of the time
#
#      candaff_angrpc    candaff_angrpcoft candaff_hprpc  candaff_hprpcoft  \
# 2791          2. No     -1. Inapplicable         2. No  -1. Inapplicable
# 3326         1. Yes  2. Most of the time         2. No  -1. Inapplicable
# 4079          2. No     -1. Inapplicable         2. No  -1. Inapplicable
#
#      candaff_afrrpc    candaff_afrrpcoft candaff_prdrpc candaff_prdrpcoft  \
# 2791          2. No     -1. Inapplicable          2. No  -1. Inapplicable
# 3326         1. Yes  4. Some of the time          2. No  -1. Inapplicable
# 4079          2. No     -1. Inapplicable          2. No  -1. Inapplicable
#
#                   libcpre_self    libcpre_choose  \
# 2791  5. Slightly conservative  -1. Inapplicable
# 3326                2. Liberal  -1. Inapplicable
# 4079           6. Conservative  -1. Inapplicable
#
#                           libcpre_dpc                      libcpre_rpc  \
# 2791             1. Extremely liberal                  6. Conservative
# 3326  4. Moderate; middle of the road        7. Extremely conservative
# 4079         5. Slightly conservative  4. Moderate; middle of the road
#
#                          libcpre_ptyd                     libcpre_ptyr  \
# 2791                       2. Liberal                  6. Conservative
# 3326  4. Moderate; middle of the road        7. Extremely conservative
# 4079         5. Slightly conservative  4. Moderate; middle of the road
#
#                              divgov_splitgov  likelypct_howlikvt1  \
# 2791  1. Better when one party controls both     -1. Inapplicable
# 3326         2. Better when control is split  1. Extremely likely
# 4079  1. Better when one party controls both     -1. Inapplicable
#
#      likelypct_whatpct1              campfin_limcorp  \
# 2791               60.0                     1. Favor
# 3326   -1. Inapplicable  3. Neither favor nor oppose
# 4079              100.0  3. Neither favor nor oppose
#
#                    campfin_banads ineq_incgap ineq_gapmore      ineq_gapless  \
# 2791  3. Neither favor nor oppose   1. Larger      1. Much  -1. Inapplicable
# 3326  3. Neither favor nor oppose   1. Larger  2. Somewhat  -1. Inapplicable
# 4079  3. Neither favor nor oppose   1. Larger      1. Much  -1. Inapplicable
#
#            ineq_incgap_x      effic_complicstd                   effic_undstd  \
# 2791      1. Much larger      -1. Inapplicable               -1. Inapplicable
# 3326  2. Somewhat larger  4. Disagree somewhat  3. Neither agree nor disagree
# 4079      1. Much larger  4. Disagree somewhat              2. Agree somewhat
#
#              effic_carestd          effic_saystd     effic_complicrev  \
# 2791      -1. Inapplicable      -1. Inapplicable  2. Most of the time
# 3326  4. Disagree somewhat  5. Disagree strongly     -1. Inapplicable
# 4079     2. Agree somewhat  4. Disagree somewhat     -1. Inapplicable
#
#           effic_undrev     effic_carerev      effic_sayrev  \
# 2791  4. Slightly well     5. Not at all       4. A little
# 3326  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
# 4079  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
#
#                    econ_ecnow               econ_ecpast    econ_ecpastamt  \
# 2791                   4. Bad  2. Stayed about the same  -1. Inapplicable
# 3326  3. Neither good nor bad          1. Gotten better           1. Much
# 4079                  2. Good          1. Gotten better       2. Somewhat
#
#                  econ_ecpast_x             econ_ecnext    econ_ecnextamt  \
# 2791  3. Stayed about the same  2. Stay about the same  -1. Inapplicable
# 3326            1. Much better           1. Get better       2. Somewhat
# 4079        2. Somewhat better  2. Stay about the same  -1. Inapplicable
#
#                econ_ecnext_x        econ_unpast       econ_unlast  \
# 2791  3. Stay about the same  2. About the same  -1. Inapplicable
# 3326      2. Somewhat better          1. Better       2. Somewhat
# 4079  3. Stay about the same          1. Better       2. Somewhat
#
#            econ_unpast_x        econ_unnext          ecblame_pres  \
# 2791   3. About the same  2. About the same           4. A little
# 3326  2. Somewhat better            3. Less  3. A moderate amount
# 4079  2. Somewhat better  2. About the same         5. Not at all
#
#          ecblame_fmpr           ecblame_dem      ecblame_rep  \
# 2791      4. A little           4. A little      4. A little
# 3326  1. A great deal  3. A moderate amount  1. A great deal
# 4079      4. A little           4. A little         2. A lot
#
#               ecblame_bank          ecblame_cons     ecblame_lend  \
# 2791  3. A moderate amount  3. A moderate amount  1. A great deal
# 3326       1. A great deal              2. A lot         2. A lot
# 4079           4. A little           4. A little      4. A little
#
#                           ptyperf_ptyecon             preswin_care  \
# 2791  3. Not much difference between them  2. Don't care very much
# 3326                         1. Democrats      1. Care a good deal
# 4079                         1. Democrats      1. Care a good deal
#
#                    preswin_win                                preswin_win_oth  \
# 2791  1. [preload: dem_pcname]  -2. Text responses available in separate file
# 3326  1. [preload: dem_pcname]  -2. Text responses available in separate file
# 4079  1. [preload: dem_pcname]  -2. Text responses available in separate file
#
#               preswin_close             preswin_state  \
# 2791       1. Will be close  1. [preload: dem_pcname]
# 3326  2. Win by quite a bit  1. [preload: dem_pcname]
# 4079       1. Will be close  1. [preload: dem_pcname]
#
#                                   preswin_state_oth   preswin_closest  \
# 2791  -2. Text responses available in separate file  1. Will be close
# 3326  -2. Text responses available in separate file  1. Will be close
# 4079  -2. Text responses available in separate file  1. Will be close
#
#      preswin_dutychoice  preswin_choiceduty    preswin_dutyst  \
# 2791   -1. Inapplicable  1. Mainly a choice  -1. Inapplicable
# 3326   -1. Inapplicable  1. Mainly a choice  -1. Inapplicable
# 4079   -1. Inapplicable    2. Mainly a duty  1. Very strongly
#
#             preswin_choicest                            preswin_dutychoice_x  \
# 2791  2. Moderately strongly  6. Moderately strongly feel voting is a choice
# 3326  2. Moderately strongly  6. Moderately strongly feel voting is a choice
# 4079        -1. Inapplicable          1. Very strongly feel voting is a duty
#
#               usworld_stronger usworld_stay        pid_self  \
# 2791                 1. Weaker     1. Agree  3. Independent
# 3326  2. Stayed about the same  2. Disagree     1. Democrat
# 4079               3. Stronger  2. Disagree     1. Democrat
#
#                pid_self_oth        pid_strong                 pid_lean  \
# 2791  -3. Restricted access  -1. Inapplicable  1. Closer to Republican
# 3326  -3. Restricted access         1. Strong         -1. Inapplicable
# 4079  -3. Restricted access         1. Strong         -1. Inapplicable
#
#                           pid_x                       tea_supp  \
# 2791  5. Independent-Republican  3. Neither support nor oppose
# 3326         1. Strong Democrat                      2. Oppose
# 4079         1. Strong Democrat  3. Neither support nor oppose
#
#            tea_suppstr                 tea_suppln                 tea_supp_x  \
# 2791  -1. Inapplicable  3. Do not lean either way  4. Do not lean either way
# 3326         1. Strong           -1. Inapplicable       7. Strong opposition
# 4079  -1. Inapplicable  3. Do not lean either way  4. Do not lean either way
#
#          ctrait_dpcmoral      ctrait_dpclead      ctrait_dpccare  \
# 2791  5. Not well at all    4. Slightly well  5. Not well at all
# 3326   1. Extremely well  3. Moderately well        2. Very well
# 4079    4. Slightly well        2. Very well   1. Extremely well
#
#          ctrait_dpcknow       ctrait_dpcint     ctrait_dpchonst  \
# 2791   4. Slightly well  3. Moderately well  5. Not well at all
# 3326  1. Extremely well   1. Extremely well   1. Extremely well
# 4079       2. Very well   1. Extremely well  3. Moderately well
#
#          ctrait_rpcmoral      ctrait_rpclead      ctrait_rpccare  \
# 2791    4. Slightly well  3. Moderately well    4. Slightly well
# 3326  5. Not well at all  5. Not well at all  5. Not well at all
# 4079    4. Slightly well  3. Moderately well  5. Not well at all
#
#           ctrait_rpcknow       ctrait_rpcint     ctrait_rpchonst  \
# 2791    4. Slightly well  3. Moderately well  3. Moderately well
# 3326  5. Not well at all  5. Not well at all  5. Not well at all
# 4079    4. Slightly well    4. Slightly well    4. Slightly well
#
#           war_worthit                war_terror spsrvpr_ssself  \
# 2791  2. Not worth it  3. Stayed about the same            3.0
# 3326      1. Worth it  3. Stayed about the same            5.0
# 4079      1. Worth it              2. Decreased            5.0
#
#                                   spsrvpr_ssdpc  \
# 2791  7. Govt should provide many more services
# 3326                                        5.0
# 4079                                        4.0
#
#                                    spsrvpr_ssrpc spsrvpr_ssdem  \
# 2791                                         4.0           6.0
# 3326  1. Govt should provide many fewer services           5.0
# 4079  1. Govt should provide many fewer services           4.0
#
#                                    spsrvpr_ssrep defsppr_self  \
# 2791                                         4.0          4.0
# 3326  1. Govt should provide many fewer services          3.0
# 4079  1. Govt should provide many fewer services          5.0
#
#                                    defsppr_dpc  \
# 2791                                       4.0
# 3326                                       3.0
# 4079  7. Govt should increase defense spending
#
#                                    defsppr_rpc defsppr_dem  \
# 2791                                       3.0         5.0
# 3326  7. Govt should increase defense spending         3.0
# 4079                                       6.0         5.0
#
#                                    defsppr_rep             inspre_self  \
# 2791                                       4.0                     3.0
# 3326  7. Govt should increase defense spending  1. Govt insurance plan
# 4079                                       5.0                     5.0
#
#                   inspre_dpc                 inspre_rpc  \
# 2791                     6.0                        6.0
# 3326                     3.0  7. Private insurance plan
# 4079  1. Govt insurance plan  7. Private insurance plan
#
#                   inspre_dem                 inspre_rep  \
# 2791                     3.0                        6.0
# 3326                     3.0  7. Private insurance plan
# 4079  1. Govt insurance plan  7. Private insurance plan
#
#                              gun_control          gun_importance guarpr_self  \
# 2791  3. Keep these rules about the same  1. Extremely important         6.0
# 3326                   1. More difficult  5. Not importantat all         4.0
# 4079                   1. More difficult    4. Not too important         4.0
#
#      guarpr_dpc                                       guarpr_rpc guarpr_dem  \
# 2791        2.0                                              5.0        3.0
# 3326        3.0  7. Govt should let each person get ahead on own        3.0
# 4079        3.0                                              5.0        3.0
#
#                                            guarpr_rep  \
# 2791                                              5.0
# 3326  7. Govt should let each person get ahead on own
# 4079                                              6.0
#
#                                            immig_policy  \
# 2791  3. Allow unauthorized immigrants to remain in ...
# 3326  3. Allow unauthorized immigrants to remain in ...
# 4079  3. Allow unauthorized immigrants to remain in ...
#
#                    immig_citizen                immig_checks  \
# 2791  3. Neither favor or oppose                   2. Oppose
# 3326                    1. Favor  3. Neither favor or oppose
# 4079                    1. Favor                   2. Oppose
#
#                             aidblack_self aidblack_dpc  \
# 2791     7. Blacks should help themselves          2.0
# 3326           1. Govt should help Blacks          2.0
# 4079  -2. Haven't thought much about this          6.0
#
#                           aidblack_rpc  \
# 2791                               4.0
# 3326  7. Blacks should help themselves
# 4079  7. Blacks should help themselves
#
#                                             envjob_self envjob_dpc  \
# 2791                                                6.0        2.0
# 3326  1. Regulate business to protect the environmen...        2.0
# 4079  7. No regulation because it will not work and ...        4.0
#
#                                              envjob_rpc  \
# 2791                                                4.0
# 3326  7. No regulation because it will not work and ...
# 4079                                                4.0
#
#                            aa_uni         aa_unifav             aa_uniopp  \
# 2791                    2. Oppose  -1. Inapplicable  2. A moderate amount
# 3326  3. Neither favor nor oppose  -1. Inapplicable      -1. Inapplicable
# 4079                     1. Favor   1. A great deal      -1. Inapplicable
#
#                          aa_uni_x                      aa_work  \
# 2791         6. Oppose moderately                    2. Oppose
# 3326  4. Neither favor nor oppose  3. Neither favor nor oppose
# 4079        1. Favor a great deal                     1. Favor
#
#                 aa_workfav            aa_workopp                    aa_work_x  \
# 2791      -1. Inapplicable  2. A moderate amount         6. Oppose moderately
# 3326      -1. Inapplicable      -1. Inapplicable  4. Neither favor nor oppose
# 4079  2. A moderate amount      -1. Inapplicable          2. Favor moderately
#
#                                   fedspend_ss fedspend_schools  \
# 2791  3. [kept about the same/ kept the same]     1. Increased
# 3326                             1. Increased     1. Increased
# 4079                             1. Increased     1. Increased
#
#                              fedspend_scitech  \
# 2791  3. [kept about the same/ kept the same]
# 3326                             1. Increased
# 4079  3. [kept about the same/ kept the same]
#
#                                fedspend_crime  \
# 2791  3. [kept about the same/ kept the same]
# 3326  3. [kept about the same/ kept the same]
# 4079                             1. Increased
#
#                              fedspend_welfare fedspend_child fedspend_poor  \
# 2791  3. [kept about the same/ kept the same]   2. Decreased  2. Decreased
# 3326  3. [kept about the same/ kept the same]   1. Increased  1. Increased
# 4079                             1. Increased   1. Increased  1. Increased
#
#                               fedspend_enviro        candrel_dpc  \
# 2791                             2. Decreased  06. Not religious
# 3326                             1. Increased       02. Catholic
# 4079  3. [kept about the same/ kept the same]  06. Not religious
#
#                                     candrel_dpc_oth        candrel_rpc  \
# 2791  -2. Text responses available in separate file         05. Mormon
# 3326  -2. Text responses available in separate file         05. Mormon
# 4079  -2. Text responses available in separate file  06. Not religious
#
#                                     candrel_rpc_oth trustgov_trustgrev  \
# 2791  -2. Text responses available in separate file           5. Never
# 3326  -2. Text responses available in separate file   -1. Inapplicable
# 4079  -2. Text responses available in separate file   -1. Inapplicable
#
#             trustgov_trustgstd                    trustgov_bigintrst  \
# 2791          -1. Inapplicable         1. Run by a few big interests
# 3326       2. Most of the time  2. For the benefit of all the people
# 4079  3. Only some of the time         1. Run by a few big interests
#
#       trustgov_waste trustgov_corrpt            trust_social  \
# 2791  1. Waste a lot         2. Most  3. About half the time
# 3326   2. Waste some        4. A few     2. Most of the time
# 4079  1. Waste a lot   3. About half     4. Some of the time
#
#      respons_elections           econcand_dwin           econcand_rwin  \
# 2791       3. Not much  2. Stay about the same  2. Stay about the same
# 3326           2. Some           1. Get better            3. Get worse
# 4079           2. Some  2. Stay about the same            3. Get worse
#
#      envir_drill          envir_nuke                        envir_gwarm  \
# 2791    1. Favor            2. Fewer  2. Probably hasn't been happening
# 3326   2. Oppose            2. Fewer     1. Has probably been happening
# 4079    1. Favor  3. The same number     1. Has probably been happening
#
#                  envir_gwgood  \
# 2791  3. Neither good nor bad
# 3326                   2. Bad
# 4079                   2. Bad
#
#                                             envir_gwhow     gayrt_discrev  \
# 2791  3. About equally by human activity and natural...         2. Oppose
# 3326                        1. Mostly by human activity  -1. Inapplicable
# 4079                        1. Mostly by human activity  -1. Inapplicable
#
#        gayrt_discstrev         gayrt_discrev_x     gayrt_discstd  \
# 2791       1. Strongly  5. Disapprove strongly  -1. Inapplicable
# 3326  -1. Inapplicable        -1. Inapplicable          1. Favor
# 4079  -1. Inapplicable        -1. Inapplicable          1. Favor
#
#        gayrt_discststd          gayrt_discstd_x  \
# 2791  -1. Inapplicable         -1. Inapplicable
# 3326       1. Strongly      1. Approve strongly
# 4079   2. Not strongly  2. Approve not strongly
#
#                                          gayrt_milrev    gayrt_milstrev  \
# 2791  1. Gays and lesbians should be allowed to serve   2. Not strongly
# 3326                                 -1. Inapplicable  -1. Inapplicable
# 4079                                 -1. Inapplicable  -1. Inapplicable
#
#                                          gayrt_milrev_x  \
# 2791  2. Feel not strongly that gays and lesbians sh...
# 3326                                   -1. Inapplicable
# 4079                                   -1. Inapplicable
#
#                                        gayrt_milstd    gayrt_milststd  \
# 2791                               -1. Inapplicable  -1. Inapplicable
# 3326      1. Homosexuals should be allowed to serve       1. Strongly
# 4079  2. Homosexuals should not be allowed to serve       1. Strongly
#
#                                          gayrt_milstd_x gayrt_adopt  \
# 2791                                   -1. Inapplicable       2. No
# 3326  1. Feel strongly that homosexuals should be al...      1. Yes
# 4079  5. Feel strongly that homosexuals should not b...       2. No
#
#                                             gayrt_marry  \
# 2791  3. There should be no legal recognition of a g...
# 3326  1. Gay and lesbian couples should be allowed t...
# 4079  3. There should be no legal recognition of a g...
#
#                                         abortpre_4point  \
# 2791     1. By law, abortion should never be permitted.
# 3326  4. By law, a woman should always be able to ob...
# 4079     1. By law, abortion should never be permitted.
#
#                                 abortpre_4point_oth penalty_favdpen  \
# 2791  -2. Text responses available in separate file        1. Favor
# 3326  -2. Text responses available in separate file       2. Oppose
# 4079  -2. Text responses available in separate file        1. Favor
#
#      penalty_dpenstr        penalty_favopp_x  presadm_secure  \
# 2791     1. Strongly     1. Approve strongly    3. No change
# 3326     1. Strongly  5. Disapprove strongly  1. More secure
# 4079     1. Strongly     1. Approve strongly    3. No change
#
#      pctlikely_whatpct2 pctlikely_howlikvt2      relig_import  \
# 2791   -1. Inapplicable  4. Slightly likely      1. Important
# 3326              100.0    -1. Inapplicable  2. Not important
# 4079   -1. Inapplicable      2. Very likely      1. Important
#
#            relig_guide               relig_pray  \
# 2791    2. Quite a bit   03. A few times a week
# 3326  -1. Inapplicable                05. Never
# 4079    2. Quite a bit  01. Several times a day
#
#                                      relig_pray_oth  \
# 2791  -2. Text responses available in separate file
# 3326  -2. Text responses available in separate file
# 4079  -2. Text responses available in separate file
#
#                                           relig_wordgod  \
# 2791  1. The bible is the actual word of god and is ...
# 3326  3. The bible is a book written by men and is n...
# 4079  1. The bible is the actual word of god and is ...
#
#                                   relig_wordgod_oth relig_church  \
# 2791  -2. Text responses available in separate file       1. Yes
# 3326  -2. Text responses available in separate file        2. No
# 4079  -2. Text responses available in separate file       1. Yes
#
#            relig_churchoft    relig_churchwk    relig_chmember  \
# 2791  2. Almost every week  -1. Inapplicable  -1. Inapplicable
# 3326      -1. Inapplicable  -1. Inapplicable             2. No
# 4079         1. Every week    1. Once a week  -1. Inapplicable
#
#                        relig_7cat_x  \
# 2791  5. Undifferentiated Christian
# 3326               8. Not religious
# 4079  5. Undifferentiated Christian
#
#                                     relig_mastersummary       relig_group  \
# 2791  010. Protestant, NFS, other, unknown, inter-, ...     1. Protestant
# 3326                            880. None (no religion)  -1. Inapplicable
# 4079  099. Christian, NFS, unknown, inter-, or non-d...          4. Other
#
#          relig_groupna                          relig_denom        relig_bapt  \
# 2791  -1. Inapplicable  22. Non-denominational - Protestant  -1. Inapplicable
# 3326  -1. Inapplicable                     -1. Inapplicable  -1. Inapplicable
# 4079  -1. Inapplicable      10. Christian or just Christian  -1. Inapplicable
#
#          relig_indbapt        relig_luth        relig_meth       relig_presb  \
# 2791  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
# 3326  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
# 4079  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
#
#            relig_refrm      relig_brethr       relig_discp     relig_chchrst  \
# 2791  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
# 3326  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
# 4079  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
#
#            relig_chgod                                         relig_pent  \
# 2791  -1. Inapplicable  -3. Restricted access text (not available thro...
# 3326  -1. Inapplicable  -3. Restricted access text (not available thro...
# 4079  -1. Inapplicable  -3. Restricted access text (not available thro...
#
#         relig_denother     relig_othxian     relig_jewisha    relig_jewishna  \
# 2791  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
# 3326  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
# 4079  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
#
#          relig_bornagn   relig_ident_1st   relig_ident_2nd   relig_ident_3rd  \
# 2791            1. Yes  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
# 3326  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
# 4079            1. Yes  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
#
#      relig_religident_prog relig_religident_nontrad relig_religident_secular  \
# 2791      1. Selected by R     0. Not selected by R     0. Not selected by R
# 3326  0. Not selected by R     0. Not selected by R     0. Not selected by R
# 4079  0. Not selected by R     0. Not selected by R     0. Not selected by R
#
#      relig_religident_agnostic relig_religident_atheist  \
# 2791      0. Not selected by R     0. Not selected by R
# 3326      0. Not selected by R         1. Selected by R
# 4079      0. Not selected by R     0. Not selected by R
#
#      relig_religident_spiritual relig_religident_none relig_religident_dkrf  \
# 2791       0. Not selected by R  0. Not selected by R  0. Not selected by R
# 3326       0. Not selected by R  0. Not selected by R  0. Not selected by R
# 4079       0. Not selected by R      1. Selected by R  0. Not selected by R
#
#                 dem_birthmo            dem_birthdy dem_birthyr dem_age_r_x  \
# 2791  -3. Restricted access  -3. Restricted access      1970.0        42.0
# 3326  -3. Restricted access  -3. Restricted access      1969.0        43.0
# 4079  -3. Restricted access  -3. Restricted access      1960.0        52.0
#
#       dem_agegrp_iwdate_x                 dem_marital       dem_partner  \
# 2791  06. Age group 40-44  1. Married: spouse present  -1. Inapplicable
# 3326  06. Age group 40-44  1. Married: spouse present  -1. Inapplicable
# 4079  08. Age group 50-54  1. Married: spouse present  -1. Inapplicable
#
#                                                 dem_edu  \
# 2791  11. Associate degree in college - occupational...
# 3326       16. Doctorate degree (for example: phd, edd)
# 4079                          08. 12th grade no diploma
#
#                 dem_edu_oth        dem_dipged  \
# 2791  -3. Restricted access  -1. Inapplicable
# 3326  -3. Restricted access  -1. Inapplicable
# 4079  -3. Restricted access  -1. Inapplicable
#
#                                       dem_edugroup_x  \
# 2791  3. Some post-high-school, no bachelor's degree
# 3326                              5. Graduate degree
# 4079             1. Less than high school credential
#
#                                               dem_edusp  \
# 2791  09. High school graduate- high school diploma ...
# 3326       16. Doctorate degree (for example: phd, edd)
# 4079                     10. Some college but no degree
#
#               dem_edusp_oth                    dem_dipgedsp  \
# 2791  -3. Restricted access  1. Graduation from high school
# 3326  -3. Restricted access                -1. Inapplicable
# 4079  -3. Restricted access                -1. Inapplicable
#
#                                     dem_eduspgroup_x dem_veteran  \
# 2791                       2. High school credential       2. No
# 3326                              5. Graduate degree       2. No
# 4079  3. Some post-high-school, no bachelor's degree       2. No
#
#        dem_milwhen_1st   dem_milwhen_2nd   dem_milwhen_3rd   dem_milwhen_4th  \
# 2791  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
# 3326  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
# 4079  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
#
#                  dem_milnow   dem_emptype_1st   dem_emptype_2nd  \
# 2791  -3. Restricted access  -1. Inapplicable  -1. Inapplicable
# 3326  -3. Restricted access  -1. Inapplicable  -1. Inapplicable
# 4079  -3. Restricted access  -1. Inapplicable  -1. Inapplicable
#
#        dem_emptype_3rd   dem_emptype_4th      dem_emptype_work  \
# 2791  -1. Inapplicable  -1. Inapplicable      1. Selected by R
# 3326  -1. Inapplicable  -1. Inapplicable  0. Not selected by R
# 4079  -1. Inapplicable  -1. Inapplicable  0. Not selected by R
#
#         dem_emptype_layoff     dem_emptype_unemp    dem_emptype_retire  \
# 2791  0. Not selected by R  0. Not selected by R  0. Not selected by R
# 3326  0. Not selected by R  0. Not selected by R  0. Not selected by R
# 4079  0. Not selected by R  0. Not selected by R  0. Not selected by R
#
#       dem_emptype_disabled    dem_emptype_hmaker   dem_emptype_student  \
# 2791  0. Not selected by R  0. Not selected by R  0. Not selected by R
# 3326  0. Not selected by R      1. Selected by R  0. Not selected by R
# 4079  0. Not selected by R      1. Selected by R  0. Not selected by R
#
#           dem_emptype_dkrf           dem_empstatus_2digitfin_x  \
# 2791  0. Not selected by R                10. Working now only
# 3326  0. Not selected by R  70. Homemaker, no other occupation
# 4079  0. Not selected by R  70. Homemaker, no other occupation
#
#                               dem_empstatus_1digitfin_x dem_empstatus_initial  \
# 2791  1. R working now (if also retired, disabled, h...      -1. Inapplicable
# 3326  7. R homemaker (if also working, working <20 h...      -1. Inapplicable
# 4079  7. R homemaker (if also working, working <20 h...      -1. Inapplicable
#
#            dem_hsworkg      dem_hsjob6mo           dem_retiremo  \
# 2791  -1. Inapplicable  -1. Inapplicable  -3. Restricted access
# 3326             2. No             2. No  -3. Restricted access
# 4079             2. No             2. No  -3. Restricted access
#
#                dem_retiredy      dem_retireyr dem_retireperiod_x  \
# 2791  -3. Restricted access  -1. Inapplicable   -1. Inapplicable
# 3326  -3. Restricted access  -1. Inapplicable   -1. Inapplicable
# 4079  -3. Restricted access  -1. Inapplicable   -1. Inapplicable
#
#             dem_everwk                                        dem_occpast  \
# 2791  -1. Inapplicable  -2. Text responses available in separate file;...
# 3326  -1. Inapplicable  -2. Text responses available in separate file;...
# 4079  -1. Inapplicable  -2. Text responses available in separate file;...
#
#                                             dem_indpast      dem_semplpst  \
# 2791  -2. Text responses available in separate file;...  -1. Inapplicable
# 3326  -2. Text responses available in separate file;...  -1. Inapplicable
# 4079  -2. Text responses available in separate file;...  -1. Inapplicable
#
#          dem_empgovpst     dem_rdjob6mon     dem_hrsrecent       dem_rdworkg  \
# 2791  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
# 3326  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
# 4079  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
#
#             dem_lookwk       dem_findjob  \
# 2791  -1. Inapplicable  -1. Inapplicable
# 3326             2. No  -1. Inapplicable
# 4079             2. No  -1. Inapplicable
#
#                                              dem_occnow  \
# 2791  -2. Text responses available in separate file;...
# 3326  -2. Text responses available in separate file;...
# 4079  -2. Text responses available in separate file;...
#
#                                              dem_indnow      dem_semplnow  \
# 2791  -2. Text responses available in separate file;...   1. Someone else
# 3326  -2. Text responses available in separate file;...  -1. Inapplicable
# 4079  -2. Text responses available in separate file;...  -1. Inapplicable
#
#          dem_empgovnow        dem_hrsnow      dem_okhrsnow       dem_losejob  \
# 2791             2. No              31.0          2. Fewer     1. Not at all
# 3326  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
# 4079  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
#
#            dem_offwork     dem_hrsreduce dem_emptypesp_1st dem_emptypesp_2nd  \
# 2791             2. No             2. No  -1. Inapplicable  -1. Inapplicable
# 3326  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
# 4079  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable  -1. Inapplicable
#
#      dem_emptypesp_3rd dem_emptypesp_4th dem_emptypesp_work  \
# ...
# 4079  2. Standard version of question(s)  2. Reverse order
#
#                  randordq_cands_parties  \
# 2791  2. Republican 1st, Democratic 2nd
# 3326  1. Democratic 1st, Republican 2nd
# 4079  2. Republican 1st, Democratic 2nd
#
#                                   randord_vote_ptynames  \
# 2791  1. Democratic names first in question texts, r...
# 3326  2. Republican names first in question texts, r...
# 4079  1. Democratic names first in question texts, r...
#
#      randordq_web_pretherms randordq_affects  \
# 2791            -2. Missing           3142.0
# 3326            -2. Missing           4132.0
# 4079            -2. Missing           2143.0
#
#                                rand_place_likelypercent  \
# 2791  1. Late placement: how likely will vote; early...
# 3326  0. Early placement: how likely will vote; late...
# 4079  1. Late placement: how likely will vote; early...
#
#            randordq_ecblame_pres   randordq_ecblame_prevpres  \
# 2791  4. 4th economic blame item  7. 7th economic blame item
# 3326  5. 5th economic blame item  1. 1st economic blame item
# 4079  5. 5th economic blame item  6. 6th economic blame item
#
#         randordq_ecblame_congdem    randordq_ecblame_congrep  \
# 2791  3. 3rd economic blame item  2. 2nd economic blame item
# 3326  4. 4th economic blame item  2. 2nd economic blame item
# 4079  1. 1st economic blame item  2. 2nd economic blame item
#
#         randordq_ecblame_wallstr  randordq_ecblame_consumers  \
# 2791  5. 5th economic blame item  1. 1st economic blame item
# 3326  7. 7th economic blame item  3. 3rd economic blame item
# 4079  4. 4th economic blame item  3. 3rd economic blame item
#
#         randordq_ecblame_lenders  \
# 2791  6. 6th economic blame item
# 3326  6. 6th economic blame item
# 4079  7. 7th economic blame item
#
#                               randord_econperf_ptynames  \
# 2791  -1. Inap, Web (same order as randordq_cands_pa...
# 3326  -1. Inap, Web (same order as randordq_cands_pa...
# 4079  -1. Inap, Web (same order as randordq_cands_pa...
#
#                                   randsplice_dutychoice  \
# 2791  2. Question version with 'choice' first (quest...
# 3326  2. Question version with 'choice' first (quest...
# 4079  2. Question version with 'choice' first (quest...
#
#          randord_pid_ptynames                 randordq_trait_moral  \
# 2791  2. Republican, Democrat  1. 1st presidential candidate trait
# 3326  1. Democrat, Republican  3. 3rd presidential candidate trait
# 4079  2. Republican, Democrat  6. 6th presidential candidate trait
#
#                     randordq_trait_strong  \
# 2791  4. 4th presidential candidate trait
# 3326  6. 6th presidential candidate trait
# 4079  3. 3rd presidential candidate trait
#
#                      randordq_trait_cares  \
# 2791  2. 2nd presidential candidate trait
# 3326  2. 2nd presidential candidate trait
# 4079  2. 2nd presidential candidate trait
#
#                       randordq_trait_know  \
# 2791  6. 6th presidential candidate trait
# 3326  5. 5th presidential candidate trait
# 4079  1. 1st presidential candidate trait
#
#                     randordq_trait_intell  \
# 2791  5. 5th presidential candidate trait
# 3326  4. 4th presidential candidate trait
# 4079  5. 5th presidential candidate trait
#
#                     randordq_trait_honest  \
# 2791  3. 3rd presidential candidate trait
# 3326  1. 1st presidential candidate trait
# 4079  4. 4th presidential candidate trait
#
#                            randsplice_fedspendtxt  \
# 2791  1. Federal spending wording: about the same
# 3326  1. Federal spending wording: about the same
# 4079  1. Federal spending wording: about the same
#
#           randordq_fedspend_socsec      randordq_fedspend_pubsch  \
# 2791  3. 3rd federal spending item  5. 5th federal spending item
# 3326  1. 1st federal spending item  2. 2nd federal spending item
# 4079  1. 1st federal spending item  2. 2nd federal spending item
#
#          randordq_fedspend_scitech       randordq_fedspend_crime  \
# 2791  4. 4th federal spending item  2. 2nd federal spending item
# 3326  6. 6th federal spending item  5. 5th federal spending item
# 4079  8. 8th federal spending item  4. 4th federal spending item
#
#          randordq_fedspend_welfare       randordq_fedspend_child  \
# 2791  1. 1st federal spending item  7. 7th federal spending item
# 3326  7. 7th federal spending item  8. 8th federal spending item
# 4079  7. 7th federal spending item  6. 6th federal spending item
#
#             randordq_fedspend_poor       randordq_fedspend_envir  \
# 2791  6. 6th federal spending item  8. 8th federal spending item
# 3326  3. 3rd federal spending item  4. 4th federal spending item
# 4079  5. 5th federal spending item  3. 3rd federal spending item
#
#      randopts_pk_medicare randopts_pk_spendleast  \
# 2791          -2. Missing            -2. Missing
# 3326          -2. Missing            -2. Missing
# 4079          -2. Missing            -2. Missing
#
#                              randord_womenperf_ptynames  \
# 2791  -1. Inap, Web (same order as randordq_cands_pa...
# 3326  -1. Inap, Web (same order as randordq_cands_pa...
# 4079  -1. Inap, Web (same order as randordq_cands_pa...
#
#       randordq_ftf_thermpo_pcpcsp  \
# 2791  -1. Inap, Web randomization
# 3326  -1. Inap, Web randomization
# 4079  -1. Inap, Web randomization
#
#                                  randordq_web_thermpopc  \
# 2791  2. Republican Pres cand 1st, Democratic Pres c...
# 3326  1. Democratic Pres cand 1st, Republican Pres c...
# 4079  2. Republican Pres cand 1st, Democratic Pres c...
#
#                                randordq_web_thermpopcsp  \
# 2791  1. Democratic Pres cand spouse 1st, Republican...
# 3326  2. Republican Pres cand spouse 1st, Democratic...
# 4079  1. Democratic Pres cand spouse 1st, Republican...
#
#                                 randordq_thermpo_hscand  \
# 2791       -1. Inap, district not determined (Web only)
# 3326  1. Democratic name 1st, if any (Dem House cand...
# 4079       -1. Inap, district not determined (Web only)
#
#                            randordq_web_thermpo_sencand  \
# 2791   -1. Inap, FTF (not randomized); no race in state
# 3326  1. Democratic Senate cand (if any) 1st, Republ...
# 4079   -1. Inap, FTF (not randomized); no race in state
#
#                            randordq_web_thermpo_senatrs  \
# 2791  -1. Inap, FTF (not randomized); Senate race in...
# 3326  -1. Inap, FTF (not randomized); Senate race in...
# 4079  -1. Inap, FTF (not randomized); Senate race in...
#
#                                randordq_web_thermpo_vpc  \
# 2791  2. Republican vice-pres cand 1st, Democratic v...
# 3326  1. Democratic vice-pres cand 1st, Republican v...
# 4079  2. Republican vice-pres cand 1st, Democratic v...
#
#              randordq_grptherm_xfund          randordq_grptherm_cath  \
# 2791  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 3326  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 4079  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
#
#            randordq_grptherm_feminst        randordq_grptherm_fedgov  \
# 2791  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 3326  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 4079  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
#
#                randordq_grptherm_lib      randordq_grptherm_midclass  \
# 2791  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 3326  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 4079  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
#
#              randordq_grptherm_labor          randordq_grptherm_poor  \
# 2791  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 3326  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 4079  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
#
#              randordq_grptherm_milit       randordq_grptherm_bigbusn  \
# 2791  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 3326  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 4079  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
#
#            randordq_grptherm_welfare       randordq_grptherm_conserv  \
# 2791  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 3326  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 4079  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
#
#            randordq_grptherm_wkclass        randordq_grptherm_suprct  \
# 2791  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 3326  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 4079  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
#
#            randordq_grptherm_gaylesb      randordq_grptherm_congress  \
# 2791  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 3326  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 4079  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
#
#               randordq_grptherm_rich        randordq_grptherm_muslim  \
# 2791  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 3326  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 4079  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
#
#              randordq_grptherm_xtian       randordq_grptherm_atheist  \
# 2791  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 3326  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 4079  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
#
#             randordq_grptherm_mormon        randordq_grptherm_teapty  \
# 2791  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 3326  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
# 4079  -1. Inap, Web (not randomized)  -1. Inap, Web (not randomized)
#
#                                    randord_mip_ptynames  \
# 2791  -1. Inap, Web (same order as randordq_cands_pa...
# 3326  -1. Inap, Web (same order as randordq_cands_pa...
# 4079  -1. Inap, Web (same order as randordq_cands_pa...
#
#             randordq_deficit_inctax      randordq_deficit_medvouch  \
# 2791  1. 1st deficit reduction item  6. 6th deficit reduction item
# 3326  5. 5th deficit reduction item  6. 6th deficit reduction item
# 4079  4. 4th deficit reduction item  3. 3rd deficit reduction item
#
#            randordq_deficit_corptax      randordq_deficit_cutmilit  \
# 2791  3. 3rd deficit reduction item  2. 2nd deficit reduction item
# 3326  3. 3rd deficit reduction item  2. 2nd deficit reduction item
# 4079  2. 2nd deficit reduction item  6. 6th deficit reduction item
#
#             randordq_deficit_fedemp       randordq_deficit_cutgovt  \
# 2791  4. 4th deficit reduction item  5. 5th deficit reduction item
# 3326  1. 1st deficit reduction item  4. 4th deficit reduction item
# 4079  1. 1st deficit reduction item  5. 5th deficit reduction item
#
#                                   randordq_ftf_abort_pc  \
# 2791  -1. Inap, Web randomization (order per randord...
# 3326  -1. Inap, Web randomization (order per randord...
# 4079  -1. Inap, Web randomization (order per randord...
#
#      randordq_abort_healthnonfatl randordq_abort_healthfatal  \
# 2791     2. 2nd abortion scenario   2. 2nd abortion scenario
# 3326     1. 1st abortion scenario   1. 1st abortion scenario
# 4079     5. 5th abortion scenario   5. 5th abortion scenario
#
#          randordq_abort_incest       randordq_abort_rape  \
# 2791  5. 5th abortion scenario  1. 1st abortion scenario
# 3326  6. 6th abortion scenario  4. 4th abortion scenario
# 4079  2. 2nd abortion scenario  4. 4th abortion scenario
#
#          randordq_abort_defect  randordq_abort_financial  \
# 2791  4. 4th abortion scenario  7. 7th abortion scenario
# 3326  3. 3rd abortion scenario  5. 5th abortion scenario
# 4079  3. 3rd abortion scenario  1. 1st abortion scenario
#
#        randordq_abort_gendpref             randord_factor_pcnamestxt  \
# 2791  6. 6th abortion scenario  1. Democratic first in question text
# 3326  2. 2nd abortion scenario  2. Republican first in quesiton text
# 4079  7. 7th abortion scenario  1. Democratic first in question text
#
#             randordq_factor_rpcreligion            randordq_factor_dpcrace  \
# 2791  6. 6th preference/aversion factor  8. 8th preference/aversion factor
# 3326  9. 9th preference/aversion factor  8. 8th preference/aversion factor
# 4079  3. 3rd preference/aversion factor  5. 5th preference/aversion factor
#
#                randordq_factor_hcarelaw            randordq_factor_economy  \
# 2791  2. 2nd preference/aversion factor  9. 9th preference/aversion factor
# 3326  1. 1st preference/aversion factor  3. 3rd preference/aversion factor
# 4079  6. 6th preference/aversion factor  8. 8th preference/aversion factor
#
#              randordq_factor_foreignpol        randordq_factor_dpcreligion  \
# 2791  3. 3rd preference/aversion factor  1. 1st preference/aversion factor
# 3326  5. 5th preference/aversion factor  7. 7th preference/aversion factor
# 4079  7. 7th preference/aversion factor  1. 1st preference/aversion factor
#
#               randordq_factor_rpcwealth           randordq_factor_dpcparty  \
# 2791  5. 5th preference/aversion factor  4. 4th preference/aversion factor
# 3326  4. 4th preference/aversion factor  2. 2nd preference/aversion factor
# 4079  4. 4th preference/aversion factor  9. 9th preference/aversion factor
#
#                randordq_factor_rpcparty randopts_pk_secytreas  \
# 2791  7. 7th preference/aversion factor           -2. Missing
# 3326  6. 6th preference/aversion factor           -2. Missing
# 4079  2. 2nd preference/aversion factor           -2. Missing
#
#      randopts_pk_pty2ndhse randopts_pk_secyun  \
# 2791           -2. Missing        -2. Missing
# 3326           -2. Missing        -2. Missing
# 4079           -2. Missing        -2. Missing
#
#              randordq_casitherm_asianam            randordq_casitherm_hisp  \
# 2791  1. 1st CASI/Web group thermometer  2. 2nd CASI/Web group thermometer
# 3326  1. 1st CASI/Web group thermometer  2. 2nd CASI/Web group thermometer
# 4079  2. 2nd CASI/Web group thermometer  5. 5th CASI/Web group thermometer
#
#                randordq_casitherm_black         randordq_casitherm_illegal  \
# 2791  3. 3rd CASI/Web group thermometer  5. 5th CASI/Web group thermometer
# 3326  4. 4th CASI/Web group thermometer  3. 3rd CASI/Web group thermometer
# 4079  1. 1st CASI/Web group thermometer  3. 3rd CASI/Web group thermometer
#
#                randordq_casitherm_white  \
# 2791  4. 4th CASI/Web group thermometer
# 3326  5. 5th CASI/Web group thermometer
# 4079  4. 4th CASI/Web group thermometer
#
#                                   randordq_stereogroups  \
# 2791  213. Order: 2 (Hispanics), 1 (Blacks), 3 (Asians)
# 3326  231. Order: 2 (Hispanics), 3 (Asians), 1 (Blacks)
# 4079  321. Order: 3 (Asians), 2 (Hispanics), 1 (Blacks)
#
#      randordq_discrim_black randordq_discrim_hisp randordq_discrim_white  \
# 2791            -2. Missing           -2. Missing            -2. Missing
# 3326            -2. Missing           -2. Missing            -2. Missing
# 4079            -2. Missing           -2. Missing            -2. Missing
#
#      randordq_discrim_gay randordq_discrim_women  \
# 2791          -2. Missing            -2. Missing
# 3326          -2. Missing            -2. Missing
# 4079          -2. Missing            -2. Missing
#
#                                    randordq_stereorelig  \
# 2791  4321. Order: 4 (Mormons), 3 (Muslims), 2 (Prot...
# 3326                                             3214.0
# 4079                                             1432.0
#
#       invited_inetrecontact2013
# 2791      1. Invited (Web only)
# 3326      1. Invited (Web only)
# 4079  0. Not invited (Web only)
#
# [3 rows x 2249 columns]

# %%
df.loc[df.duplicated(),]
# Out:
# Empty DataFrame
# Columns: [version, caseid, weight_ftf, weight_web, weight_full, psu_full, psu_ftf, strata_full, strata_ftf, ftf_oversample, wave_completions, mode, gend_gendobs, gender_respondent_x, interest_attention, interest_following, interest_wherevote, interest_voted2008, interest_whovote2008, interest_whovote2008_oth, prmedia_useinet, prmedia_wkinews, prmedia_atinews, prmedia_wktvnws, prmedia_attvnews, prmedia_wkpaprnws, prmedia_atpprnews, prmedia_wkrdnws, prmedia_atrdnews, prevote_regist_addr, prevote_regist_noaddr, prevote_reg, prevote_reg_recordstate, prevote_reg_recordcity, prevote_reg_state, prevote_reg_samestate, prevote_regincnty, prevote_regyrs3cat, prevote_regyrsfull, prevote_regname, prevote_regpty_state, prevote_regpty, prevote_regpty_oth, prevote_regint, prevote_primv, prevote_primvwho, prevote_primvwho_oth, prevote_voted, prevote_vconf, prevote_howvote, prevote_ckbcard, prevote_ballot_color, prevote_presvt, prevote_presvtwho, prevote_presvtwho_oth, prevote_presstr, prevote_vtpresdec, prevote_vtpresdec_dkrf, prevote_intpres, prevote_intpreswho, prevote_intpreswho_oth, prevote_intpresst, prevote_prefpres, prevote_prefprwho, prevote_prefprwho_oth, prevote_prefprstr, prevote_votehs, prevote_hsvtbc, prevote_hsvtnobc, prevote_inths, prevote_inthsbc, prevote_inthsnobc, prevote_hspref, prevote_hsprefbc, prevote_hsprefnobc, prevote_senhhstate, prevote_senregstate, prevote_votesen, prevote_vtsenbc, prevote_vtsennobc, prevote_intsen, prevote_intsenbc, prevote_intsennobc, prevote_senpref, prevote_senprefbc, prevote_senprefnobc, prevote_govhhstate, prevote_govregstate, prevote_votegov, prevote_vtgovbc, prevote_vtgovnobc, prevote_intgov, prevote_intgovbc, prevote_intgovnobc, prevote_govpref, prevote_govprefbc, prevote_govprefnobc, candlik_likedpc, candlik_likewhatdpc, candlik_disldpc, ...]
# Index: []
#
# [0 rows x 2249 columns]

# %% [markdown]
# ## Interesting Columns
#
# * V161086: (PRE) Thermometer - Democratic Presidential Candidate
# * V161087: (PRE) Thermometer - Republican Presidential Candidate
#
# * ~V162078: (POST) Thermometer - Democratic Presidential Candidate~
# * ~V162079: (POST) Thermometer - Republican Presidential Candidate~
#
# * V160001: Study Respondent Number: Year-Level CaseID
# * ~VCF0009z: Weight (???)~ see table below
# * V160501: Mode of Interview
# * V161267: (PRE) Respondent - Age
# * V161342: Respondent - R self-identified gender
#
# * V165702: Interview Start Date
# * V165703: Interview Start Time
# * V165704: Interview End Date
# * V165705: Interview End Time
#
#
# * V161155: PRE: party ID: Does R think of self as Dem, Rep, Ind or what?

# %% [markdown]
# _Weights_
# To analyze the complete dataset (both web and face‐to‐face modes) using variables from the post‐
# election survey only or from both the pre‐election and post‐election questionnaires, use the weight
# V160102. For analysis of the complete dataset using only the pre‐election questionnaire data, use the
# weight V160101.
#
# _From page 6 of the codebook_
#
# * V160101w: Internet mode alone, using data from only the pre‐election survey
#
# Since we are working only with web data (becauase that is the one with the survey date mentioned) we would need to use `V160101w` only

# %% [markdown]
# ## Rename Columns
#
# These column names are too unfriendly to work with.  We can rename them

# %%
interesting_cols = ['V161086', 'V161087', 'V160001', 'V160501', 'V161267', 'V161342', 'V165702', 'V165703', 
           'V165704', 'V165705', 'V161155']
df_clean = df[interesting_cols]
df_clean
# Out:
#      V161086 V161087  V160001       V160501 V161267    V161342  \
# 0        0.0    85.0      1.0  1. FTF /CASI    29.0    1. Male
# 1        0.0    85.0      2.0  1. FTF /CASI    26.0    1. Male
# 2       50.0    60.0      3.0  1. FTF /CASI    23.0    1. Male
# 3        0.0    60.0      4.0  1. FTF /CASI    58.0    1. Male
# 4       15.0     0.0      5.0  1. FTF /CASI    38.0  2. Female
# ...      ...     ...      ...           ...     ...        ...
# 4265    86.0     3.0   5086.0        2. Web    37.0  2. Female
# 4266    50.0   100.0   5087.0        2. Web    82.0    1. Male
# 4267     0.0    86.0   5088.0        2. Web    27.0    1. Male
# 4268    85.0     0.0   5089.0        2. Web    39.0  2. Female
# 4269    60.0    40.0   5090.0        2. Web    52.0    1. Male
#
#                            V165702                       V165703  \
# 0     -2. Inapplicable, FTF sample  -2. Inapplicable, FTF sample
# 1     -2. Inapplicable, FTF sample  -2. Inapplicable, FTF sample
# 2     -2. Inapplicable, FTF sample  -2. Inapplicable, FTF sample
# 3     -2. Inapplicable, FTF sample  -2. Inapplicable, FTF sample
# 4     -2. Inapplicable, FTF sample  -2. Inapplicable, FTF sample
# ...                            ...                           ...
# 4265                      20161028                        050427
# 4266                      20160919                        124955
# 4267                      20161018                        175632
# 4268                      20161021                        054746
# 4269                      20161019                        191857
#
#                            V165704                       V165705  \
# 0     -2. Inapplicable, FTF sample  -2. Inapplicable, FTF sample
# 1     -2. Inapplicable, FTF sample  -2. Inapplicable, FTF sample
# 2     -2. Inapplicable, FTF sample  -2. Inapplicable, FTF sample
# 3     -2. Inapplicable, FTF sample  -2. Inapplicable, FTF sample
# 4     -2. Inapplicable, FTF sample  -2. Inapplicable, FTF sample
# ...                            ...                           ...
# 4265                      20161028                        050846
# 4266                      20160919                        130021
# 4267                      20161018                        175922
# 4268                      20161021                        054849
# 4269                      20161019                        192434
#
#                           V161155
# 0                   2. Republican
# 1                   2. Republican
# 2                  3. Independent
# 3     0. No preference (FTF ONLY)
# 4                  3. Independent
# ...                           ...
# 4265                  1. Democrat
# 4266                  1. Democrat
# 4267                  1. Democrat
# 4268                  1. Democrat
# 4269                2. Republican
#
# [4270 rows x 11 columns]

# %%
df_clean.rename(
    columns={
        'V161086': 'ft_dem',                       # * V161086: (PRE) Thermometer - Democratic Presidential Candidate
        'V161087': 'ft_rep',                       # * V161087: (PRE) Thermometer - Republican Presidential Candidate
        'V160001': 'caseid',                       # * V160001: Study Respondent Number: Year-Level CaseID
        'V160501': 'interview_mode',               # * V160501: Mode of Interview
        'V161267': 'age',                          # * V161267: (PRE) Respondent - Age
        'V161342': 'gender',                       # * V161342: Respondent - R self-identified gender
        'V165702': 'interview_start_date',         # * V165702: Interview Start Date
        'V165703': 'interview_start_time',         # * V165703: Interview Start Time
        'V165704': 'interview_end_date',           # * V165704: Interview End Date
        'V165705': 'interview_end_time',           # * V165705: Interview End Time
        'V161155': 'party_id'                      # * V161155: PRE: party ID: Does R think of self as Dem, Rep, Ind or what?
    }, 
inplace=True)

df_clean
# Out:
# /tmp/ipykernel_393074/408802456.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.rename(
#      ft_dem ft_rep  caseid interview_mode   age     gender  \
# 0       0.0   85.0     1.0   1. FTF /CASI  29.0    1. Male
# 1       0.0   85.0     2.0   1. FTF /CASI  26.0    1. Male
# 2      50.0   60.0     3.0   1. FTF /CASI  23.0    1. Male
# 3       0.0   60.0     4.0   1. FTF /CASI  58.0    1. Male
# 4      15.0    0.0     5.0   1. FTF /CASI  38.0  2. Female
# ...     ...    ...     ...            ...   ...        ...
# 4265   86.0    3.0  5086.0         2. Web  37.0  2. Female
# 4266   50.0  100.0  5087.0         2. Web  82.0    1. Male
# 4267    0.0   86.0  5088.0         2. Web  27.0    1. Male
# 4268   85.0    0.0  5089.0         2. Web  39.0  2. Female
# 4269   60.0   40.0  5090.0         2. Web  52.0    1. Male
#
#               interview_start_date          interview_start_time  \
# 0     -2. Inapplicable, FTF sample  -2. Inapplicable, FTF sample
# 1     -2. Inapplicable, FTF sample  -2. Inapplicable, FTF sample
# 2     -2. Inapplicable, FTF sample  -2. Inapplicable, FTF sample
# 3     -2. Inapplicable, FTF sample  -2. Inapplicable, FTF sample
# 4     -2. Inapplicable, FTF sample  -2. Inapplicable, FTF sample
# ...                            ...                           ...
# 4265                      20161028                        050427
# 4266                      20160919                        124955
# 4267                      20161018                        175632
# 4268                      20161021                        054746
# 4269                      20161019                        191857
#
#                 interview_end_date            interview_end_time  \
# 0     -2. Inapplicable, FTF sample  -2. Inapplicable, FTF sample
# 1     -2. Inapplicable, FTF sample  -2. Inapplicable, FTF sample
# 2     -2. Inapplicable, FTF sample  -2. Inapplicable, FTF sample
# 3     -2. Inapplicable, FTF sample  -2. Inapplicable, FTF sample
# 4     -2. Inapplicable, FTF sample  -2. Inapplicable, FTF sample
# ...                            ...                           ...
# 4265                      20161028                        050846
# 4266                      20160919                        130021
# 4267                      20161018                        175922
# 4268                      20161021                        054849
# 4269                      20161019                        192434
#
#                          party_id
# 0                   2. Republican
# 1                   2. Republican
# 2                  3. Independent
# 3     0. No preference (FTF ONLY)
# 4                  3. Independent
# ...                           ...
# 4265                  1. Democrat
# 4266                  1. Democrat
# 4267                  1. Democrat
# 4268                  1. Democrat
# 4269                2. Republican
#
# [4270 rows x 11 columns]

# %% [markdown]
# ## Remove FTF Data
#
# FTF samples don't contain the start date or time of the interview

# %%
df_clean = df_clean[df_clean["interview_mode"] == "2. Web"]
df_clean
# Out:
#      ft_dem        ft_rep  caseid interview_mode   age     gender  \
# 1180   71.0           2.0  2001.0         2. Web  51.0    1. Male
# 1181   50.0  -99. Refused  2002.0         2. Web  26.0    1. Male
# 1182   85.0           0.0  2003.0         2. Web  56.0    1. Male
# 1183   70.0           0.0  2004.0         2. Web  20.0  2. Female
# 1184   42.0          50.0  2005.0         2. Web  26.0  2. Female
# ...     ...           ...     ...            ...   ...        ...
# 4265   86.0           3.0  5086.0         2. Web  37.0  2. Female
# 4266   50.0         100.0  5087.0         2. Web  82.0    1. Male
# 4267    0.0          86.0  5088.0         2. Web  27.0    1. Male
# 4268   85.0           0.0  5089.0         2. Web  39.0  2. Female
# 4269   60.0          40.0  5090.0         2. Web  52.0    1. Male
#
#      interview_start_date interview_start_time interview_end_date  \
# 1180             20160916               202052           20160916
# 1181             20160929               040557           20160929
# 1182             20161031               163935           20161031
# 1183             20161029               222111           20161029
# 1184             20160914               034508           20160914
# ...                   ...                  ...                ...
# 4265             20161028               050427           20161028
# 4266             20160919               124955           20160919
# 4267             20161018               175632           20161018
# 4268             20161021               054746           20161021
# 4269             20161019               191857           20161019
#
#      interview_end_time                party_id
# 1180             202735          3. Independent
# 1181             041112          3. Independent
# 1182             164031           2. Republican
# 1183             222815             1. Democrat
# 1184             034623  5. Other party SPECIFY
# ...                 ...                     ...
# 4265             050846             1. Democrat
# 4266             130021             1. Democrat
# 4267             175922             1. Democrat
# 4268             054849             1. Democrat
# 4269             192434           2. Republican
#
# [3090 rows x 11 columns]

# %% [markdown]
# ### Is there anyone without a Feeling Thermometer?

# %%
df_clean = df_clean[ ~df_clean["ft_dem"].str.startswith('-99', na=False) ]  # Refused
df_clean = df_clean[ ~df_clean["ft_dem"].str.startswith('-88', na=False) ]  # Don't Know

# %%
df_clean = df_clean[ ~df_clean["ft_rep"].str.startswith('-99', na=False) ]
df_clean = df_clean[ ~df_clean["ft_rep"].str.startswith('-88', na=False) ]

# %% [markdown]
# ## Proper column types
# Fix the column types so that they are interpreted properly

# %%
df_clean["ft_dem"] = pd.to_numeric(df_clean["ft_dem"])
df_clean["ft_rep"] = pd.to_numeric(df_clean["ft_rep"])

# %%
df_clean["interview_start_date"] = pd.to_datetime(df_clean["interview_start_date"])
df_clean["interview_end_date"] = pd.to_datetime(df_clean["interview_end_date"])

# %%
df_clean["interview_start_time"] = pd.to_datetime(df_clean["interview_start_time"], format="%H%M%S")
df_clean["interview_end_time"] = pd.to_datetime(df_clean["interview_end_time"], format="%H%M%S")

# %% [markdown]
# ## Any interviews that crossed days?

# %%
n_multidaysurveys = len(df_clean[df_clean["interview_start_date"] != df_clean["interview_end_date"]])
n_singledaysurveys = len(df_clean[df_clean["interview_start_date"] == df_clean["interview_end_date"]])



print(f"{n_multidaysurveys=}; {n_singledaysurveys=}")
# Out:
# n_multidaysurveys=45; n_singledaysurveys=2989

# %% [markdown]
# ## Save the Clean Dataset

# %%
# df_clean.to_csv("2016_clean.csv")

# %%
#df_clean = pd.read_csv("2016_clean.csv")

# %% [markdown]
# ## Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

demblue = "#0015BC"
repred = "#FF0000"
demgrey = "#9EA4BF"
repgrey = "#BF9EA2"

# %%
fig, ax = plt.subplots()
sns.histplot(
    data = df_clean,
    x = "ft_dem",
    ax=ax,
    palette=[demblue],
)
# Out:
# <AxesSubplot:xlabel='ft_dem', ylabel='Count'>

# %%
fig, ax = plt.subplots()
sns.histplot(
    data = df_clean,
    x = "ft_rep",
    ax=ax,
    palette=[repred],
)
# Out:
# <AxesSubplot:xlabel='ft_rep', ylabel='Count'>

# %%
fig, ax = plt.subplots(figsize=(16, 8))
sns.kdeplot(
    data = df_clean,
    x = "ft_dem",
    ax = ax,
    color = demblue,
    label = 'Clinton'
)
sns.kdeplot(
    data = df_clean,
    x = "ft_rep",
    ax = ax,
    color = repred,
    label = 'Trump'
)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_xlabel("Feeling Thermometer Temperature", fontsize=16)
ax.set_ylabel("Density of Respondents", fontsize=16)
ax.set_title("2016", fontsize=22)

plt.legend()

# %% [markdown]
# ## Date Window

# %%
import datetime

start_date = datetime.datetime(2016, 10, 25)
end_date = datetime.datetime(2016, 11, 1)

print(f"{start_date=}; {end_date=}")
# Out:
# start_date=datetime.datetime(2016, 10, 25, 0, 0); end_date=datetime.datetime(2016, 11, 1, 0, 0)

# %%
df_clean = df_clean[ df_clean["interview_start_date"] >= start_date ]

# %%
df_clean = df_clean[ df_clean["interview_end_date"] <= start_date ]

# %%
len(df_clean)
# Out:
# 31
